# %% [markdown]
# # Ticket Classification Exploration
#
# This notebook explores the incident dataset, classification labels, and feature extraction for the agentic incident triage platform.

# %%
import json
from pathlib import Path

path = Path('../data/raw/sample_incidents.json')
with path.open('r', encoding='utf-8') as f:
    incidents = json.load(f)

print(f'Total incidents: {len(incidents)}')
print(incidents[0])"
: {
: {
: 
3
,
: 
,
: 

: {
: 
,
: 
3.11

: 4,
: 5
